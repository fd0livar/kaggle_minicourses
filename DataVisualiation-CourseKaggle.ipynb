# %% [markdown]
# # Data Visualization
# *Make great data visualizations. A great way to see the power of coding!*
#
# # 1. Hello, Seaborn
# *Your first introduction to coding for data visualization*
#
# ## Welcome to Data Visualization!
# This course is to learn how to use Seaborn, a powerful visualization tool.

# %%
import pandas as pd 
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print('Setup complete')
# Out:
# Setup complete

# %%
# Data of historical Fifa ranking for 6 different countries
fifa_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\FifaData\\fifa.csv'
fifa_data = pd.read_csv(fifa_filepath, index_col='Date', parse_dates=True)

# %%
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# ### Plot the data
# There are many ways to plot data. Sometimes you need only one line of code to do so

# %%
# Set the width and height of the figure
plt.figure(figsize=(16, 6))

# Line-chart showing how FIFA ranking evolved over time
sns.lineplot(data=fifa_data)

# %% [markdown]
# ---
# # 2. Line Charts
# Visualize trends over time
#
# Select the data and load it. We'll work with data from spotify tracking the daily streaming of 5 popular songs:

# %%
spotify_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\SpotifyData\\spotify.csv'
spotify_data = pd.read_csv(spotify_filepath, index_col='Date', parse_dates=True)

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# ### Plot the Data
# Now that the dataset is loaded into the notebook, we need only one line of code to make a line chart.

# %%
sns.lineplot(data=spotify_data)

# %% [markdown]
# `sns.lineplot` is the command to tell seaborn we want a lineplot. If we want a different type of plot, we modify that (`sns.barplot`, `sns.heatmap`, etc).
#
# You can also change additional detail, such as title, figure size:

# %%
# Set the width and height of the figure
plt.figure(figsize=(14, 6)) # 14 inches (in width) and 6 inches (in height)

# Add title
plt.title('Daily Global Streams of Popular Songs in 2017-2018')

# Line chart of the data
sns.lineplot(data=spotify_data)

# %% [markdown]
# ### Plot a subset of the data
# Let's first print the column names:

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# Now we'll plot only 2 columns of the dataset

# %%
plt.figure(figsize=(14, 6))
plt.title('Daily Global Streams of Popular Songs in 2017-2018')
sns.lineplot(data=spotify_data['Shape of You'], label='Shape of You')
sns.lineplot(data=spotify_data['Despacito'], label='Despacito')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# This way we can select single columns from the dataset.

# %% [markdown]
# ---
# # 3. Bar Charts and Heatmaps
# *use color or length to compare categories in a dataset*

# %%
flight_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\FlightsData\\flight_delays.csv'
flight_data = pd.read_csv(flight_filepath, index_col='Month')

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %% [markdown]
# Each entry shows the average arrival delay (in minutes) for a different airline and month (all in year 2015). Negative entries denote flights that (on average) tended to arrive early. For example AA (American Airlines) aarived in January roughly 7 minutes late.
# We dont use `parse_dates=True` since the Month column is not a date.
#
# ## Bar Chart
# We'd like to create a bar chart for Spirit Airlines (code: **NK**) flights, by month:

# %%
plt.figure(figsize=(10, 6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(x=flight_data.index, y=flight_data['NK'])
plt.ylabel('Arrival delay (in minutes)')
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# When determining what to use as the horizontal axis, we selected the column that indexes the rows. We must select the indexing column with `flight_data.index` since that is the way we loaded the dataset. It's not possible to use `flight_data['Month']`, which will return an error.
#
# ## Heatmap
#
# Here we will plot the data with a heatmap. This will help us visualize patters in the data.

# %%
plt.figure(figsize=(14, 7))
plt.title('Average Arrival Delay for each Airline, by Month')
sns.heatmap(data=flight_data, annot=True)
plt.xlabel('Airline')
# Out:
# Text(0.5, 42.0, 'Airline')

# %% [markdown]
# `annot=True`: This ensures that the values for each cell appear on the chart.
#
# At first sight you can see that at the end of the year, the airlines have less delays!
#
# ---
# # 4. Scatter Plots
# *Leverage the coordinate plane to explore relationships between variables*
#
# ## Load and examine the data
# We'll work with a synthetic dataset of insurance charges, to see ifwe can understand why some customers pay more than others.

# %%
insurance_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\InsuranceData\\insurance.csv'
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Scatter Plots
# We use the `sns.scatterplot` command and specify the values for:
# - the horizontal x-axis (`x=insurance_data['bmi'])`, and
# - the vertical y-axis (`y=insurance_data['charges'])`.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# This might suggest that the higher the *BMI*, the higher the *charges*. This makes sense since a higher *BMI* is associated to a higher risk of chronic disease.
#
# To double check the strength of this relationship, we can add a regression line by changing the command to `sns.regplot`.

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# ## Color-coded scatter plots
#
# We can use scatter plots to display the relationships between three variables! One way of doing this is by color-coding the points.
#
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by `'smoker'`, and plot the other two columns (`'bmi'`, `'charges'`) on the axes.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])

# %% [markdown]
# Here we can see two trends, charges increases with BMI, but the slope is much higher for smokers. We can add two regression lines with `sns.lmplot` (Note that the command plot plotting using `sns.lmplot` is different than the previous commands)

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %% [markdown]
# Now we will use a different type of plot: the **Categorical Scatter Plot**, where one of the axes has a categorical variable (like `smoker`). We build it with the `sns.swarmplot` command:

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])

# %% [markdown]
# Among other things, this plot shows:
# - On average, non-smokers are charged less than smokers
# - the customers who pay the most are smokers, whereas the customers who pay the least are non-smokers.
#
#
# ---
# # 5. Distributions
# *Create histograms and density plots*
#
# We will work with a dataset of 150 different flowers, or 50 each from three different species of iris (Iris setosa, Iris versicolor, and Iris virginica).

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
iris_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\IrisData\\iris.csv'
iris_data = pd.read_csv(iris_filepath, index_col='Id')
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ## Histrograms
# Say we want to create a histogram to see how petal length varies in iris flowers. We can do this with `sns.distplot` command.

# %%
# Histogram
sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)

# %% [markdown]
# We have customized the behaviour of the command with 2 additional pieces of information:
# - `a=` chooses the column we'd like to plot
# - `kde=False` is something we'll always provide when creating a histogram, as leaving it out will create a slightly different plot.
#
# ## Density Plots
# The next type of plot is a **kernel density estimate (KDE)** plot. You can think of it as a smoothed histogram.
#
# To make a KDE plot, we use the `sns.kdeplot` command. Setting `shade=True` colors the area below the curve (and `data=` has identical functionality as when we made the histogram above).

# %%
# KDE plot
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)

# %% [markdown]
# ## 2D KDE plots
#
# We're not restricted to a single column when creating a KDE plot. We can create a **two-dimensional (2D) KDE plot** with the `sns.jointplot` command.
#
# In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.

# %%
# 2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind='kde')

# %% [markdown]
# Note that in addition to the 2D KDE plot, we have the 1D KDE plot at the top and on the right, for each variable, `iris_data['Petal Length (cm)]` and `iris_data['Sepal Width (cm)]` respectively.
#
#
# ## Color-coded plots
#
# We'll create plots to understand differences between the species. To accomplish this, we begin by breaking the dataset into three separate files, with one for each species:

# %%
# Paths of the files to read
iris_set_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\IrisData\\iris_setosa.csv'
iris_ver_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\IrisData\\iris_versicolor.csv'
iris_vir_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\IrisData\\iris_virginica.csv'

# Read the files into variables
iris_set_data = pd.read_csv(iris_set_filepath, index_col='Id')
iris_ver_data = pd.read_csv(iris_ver_filepath, index_col='Id')
iris_vir_data = pd.read_csv(iris_vir_filepath, index_col='Id')

# Print the first 5 rows of the Iris versicolor data
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %% [markdown]
# In the code cell below, we create a different histogram for each species by using the `sns.distplot` command (as above) three times. We use `label=` to set how each histogram will appear in the legend.

# %%
# histograms for each species
sns.distplot(a=iris_set_data['Petal Length (cm)'], label='Iris-setosa', kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label='Iris-versicolor', kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label='Iris-virginica', kde=False)

# Add title
plt.title('Histogram of Petal Lengths, by Species')

# Force legend to appear
plt.legend()

# %% [markdown]
# In this case, the legend does not automatically appear on the plot, thus we need to force it with `plt.legend()`.
#
# We can also create a KDE plot for each species by using `sns.kdeplot`

# %%
# KDE plot for each species
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label='Iris-setosa', shade=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label='Iris-versicolor', shade=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label='Iris-virginica', shade=True)

# Add title
plt.title('Distribution of Petal Lengths, by Species')
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %% [markdown]
# One interesting pattern that can be seen in plots is that the plants seem to belong to one of two groups, where Iris versicolor and Iris virginica seem to have similar values for petal length, while Iris setosa belongs in a category all by itself.
#
# In fact, according to this dataset, we might even be able to classify any iris plant as Iris setosa (as opposed to Iris versicolor or Iris virginica) just by looking at the petal length: if the petal length of an iris flower is less than 2 cm, it's most likely to be Iris setosa!
#
#
# ---
# # 6. Choosing Plot Types and Custom Styles
# *Customize your charts and make them look snazzy (?)*
#
# ## Summary
#
# How to decide the best chart to best *tell the story of the data*? We can separate the types of charts into three separate broad categories:
#
# - Trends - A trend is defined as a pattern of change.
#  - `sns.lineplot` - **Line charts** are the best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# - Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
#  - `sns.barplot` - **Bar charts** are useful for comparating quantities corresponding to different groups.
#  - `sns.heatmap` - **Heatmaps** can be used to find color-coded patterns in tables of numbers.
#  - `sns.scatterplot` - **Scatter plots** show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third *categorical variable*.
#  - `sns.regplot` - Inclusing a **regression line** in the scatter plot makes it easier to see any linear relationship between two variables.
#  - `sns.lmplot` - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#  - `sns.swarmplot` - **Categorical scatter plots** show the relationship between a continuous variable and a categorical variable.
#
# - Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#  - `sns.distplot` - **Histograms** show the distribution of a single numerical variable.
#  - `sns.kdeplot` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#  - `sns.jointplot` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# ## Changing styles with seaborn
#
# All of the commands have provided a nice, default style to each of the plots. However, you may find it useful to customize how your plots look, and thankfully, this can be accomplished by just adding one more line of code!

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# We'll work with the data from the spotify trend:

# %%
spotify_filepath = 'C:\\Users\\fdoli\\github\\Kaggle\\SpotifyData\\spotify.csv'
spotify_data = pd.read_csv(spotify_filepath, index_col='Date', parse_dates=True)

plt.figure(figsize=(12, 6))
sns.lineplot(data=spotify_data)

# %% [markdown]
# We can change the style of the figure

# %%
sns.set_style('dark')
plt.figure(figsize=(12, 6))
sns.lineplot(data=spotify_data)

# %% [markdown]
# Seaborn has five different themes: (1)`"darkgrid"`, (2)`"whitegrid"`, (3)`"dark"`, (4)`"white"`, and (5)`"ticks"`, and you need only use a command similar to the one in the code cell above (with the chosen theme filled in) to change it.
#
#
# ---
# # 7. Final Project
# *Practice for real-world application*

# %%
sns.swarmplot(x=insurance_data['smoker'][:30], y=insurance_data['charges'][:30])
